# %%
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Demo: Reproduction

# %%
import acmark_model as acmark
from load_dataset import load_data
import matplotlib.pyplot as plt
# import seaborn as sns
import scipy.sparse as sp
import copy

from sklearn.metrics import mean_squared_error as mse

# %% [markdown]
# ## load dataset

# %%
file_names = ['./datasets/cora_ml.npz']
file_name = file_names[0]

S_ori,C,n,m,k = load_data(file_name)
# Out:
# Selecting 1 largest connected components
# number of nodes : 2810
# number of edges : 7981
# number of classes : 7

# %% [markdown]
# # acMark

# %%
d = 10 # number of attributes
S,X,Label = acmark.acmark_reproduction(S_ori,C,d)
# Out:
# class size disribution : [345, 433, 398, 414, 755, 141, 324]
# finished 10%
# finished 20%
# finished 30%
# finished 40%
# finished 50%
# finished 60%
# finished 70%
# finished 80%
# finished 90%
# number of generated edges : 7677

# %%
from func import S_class_order
S_class = S_class_order(S, n, k, Label)
    
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("node ID", size = 24)
ax.set_ylabel("node ID", size = 24)
plt.rcParams["font.size"] = 20
ax.spy(S_class, markersize=.2)
ticks = [0,1000,2000]
ax.set_xticks(ticks)
ax.set_yticks(ticks)
plt.show()
# Out:
# community size : [345, 433, 398, 414, 755, 141, 324]
# {4: 755, 1: 433, 3: 414, 2: 398, 0: 345, 6: 324, 5: 141}
# 2810

# %% [markdown]
# ## changing size

# %%
z=12
n=2**z
m=2**(z+5)
d=10

# %%
S,X,Label = acmark.acmark_reproduction(S_ori,C,d,n=n,m=m,max_deg=int(n/2**(z-9)))
# Out:
# class size disribution : [504, 607, 683, 536, 1131, 195, 440]
# finished 10%
# finished 20%
# finished 30%
# finished 40%
# finished 50%
# finished 60%
# finished 70%
# finished 80%
# finished 90%
# number of generated edges : 117653
